# %%
from bs4 import BeautifulSoup
import urllib.request

parser = 'html.parser'  # or 'lxml' (preferred) or 'html5lib', if installed
resp = urllib.request.urlopen("https://iextrading.com/trading/market-data/")
soup = BeautifulSoup(resp, parser, from_encoding=resp.info().get_param('charset'))

for link in soup.find_all('a', href=True):
    print(link['href'])
# Out:
# /privacy/
# /
# /trading/
# /regulation/
# /stats/
# /apps/
# /developer/
# /status/
# /about/
# /listing-center/
# /about/press/
# /trading/documents/
# /careers/
# /account/
# /trading/
# /trading/order-types/
# /trading/market-data/
# /trading/fees/
# /trading/documents/
# /behind-the-trade/
# /trading/router/
# /trading/alerts/
# /trading/#hours
# /trading/membership/
# /trading/alerts/
# /listing-center/security/notices/
# /stats/
# /stats/#last-trading-day
# /stats/#recent-stats
# /apps/market/
# /stats/#historical-stats
# /apps/stocks/
# /apps/tops/
# /apps/market/
# /developers/
# /developers/docs/
# /trading/market-data/
# https://iexcloud.io/
# /brand/
# /regulation/
# /regulation/rule-filings/
# /regulation/circulars/
# /docs/Investors Exchange Rule Book.pdf
# /regulation/disciplinary-actions/
# /insights/
# /policy/
# /policy/testimony/2019/
# /about/
# /about/#our-team
# /about/leadership/
# /about/press/
# https://medium.com/boxes-and-lines
# /podcast/
# /careers/
# /account/
# /status/
# /trading/market-data/
# #deep
# #tops
# #hist
# #specifications
# #pricing
# #agreements
# #access
# #hist-download
# #deep
# #tops
# #hist
# #hist-download
# /iex-historical-data-terms/
# #specifications
# /docs/IEX DEEP Specification.pdf
# /docs/IEX Transport Specification.pdf
# https://www.googleapis.com/download/storage/v1/b/iex/o/data%2Ffeeds%2F20180127%2F20180127_IEXTP1_DEEP1.0.pcap.gz?generation=1517101215560431&alt=media
# /docs/IEX TOPS Specification.pdf
# /docs/IEX Transport Specification.pdf
# https://www.googleapis.com/download/storage/v1/b/iex/o/data%2Ffeeds%2F20180127%2F20180127_IEXTP1_TOPS1.6.pcap.gz?generation=1517101257197858&alt=media
# /docs/IEX TOPS Specification v1.5.pdf
# #pricing
# #agreements
# /docs/IEX Data Recipient Agreement and Forms.pdf
# /docs/IEX Data Subscriber Agreement.pdf
# /docs/IEX Connectivity Services Agreement and Forms.pdf
# #access
# #hist-download
# /iex-historical-data-terms/
# https://iexcloud.io/
# tel:6463432110
# mailto:sales@iextrading.com
# mailto:marketops@iextrading.com
# tel:6463432200
# mailto:sre@iextrading.com
# https://iexcloud.io/support/
# mailto:support@iexcloud.io
# tel:6463432130
# mailto:marcomms@iextrading.com
# /status/
# /
# /account/
# /about/
# /careers/
# /about/leadership/
# /about/press/
# /about/#our-team
# https://medium.com/boxes-and-lines
# /podcast/
# /trading/
# /trading/membership/
# /trading/documents/
# /trading/fees/
# /trading/#hours
# /trading/auctions/
# /trading/eligible-symbols/
# /trading/#members
# /trading/#partners
# /trading/market-data/
# /trading/order-types/
# /trading/router/
# /trading/alerts/
# /behind-the-trade/
# /stats/
# /stats/#last-trading-day
# /stats/#recent-stats
# /stats/#historical-stats
# /listing-center/
# /listing-center/issuer-services/
# /listing-center/security/daily-list/
# /listing-center/security/short-interest/
# /listing-center/security/threshold-securities/
# /listing-center/security/notices/
# /apps/
# /apps/stocks/
# /apps/tops/
# /apps/market/
# /apps/#iex
# /developers/
# /developer/docs/
# /brand/
# /regulation/
# /regulation/rule-filings/
# /regulation/finra-rules/
# /regulation/circulars/
# /regulation/governance/
# /regulation/disciplinary-actions/
# /regulation/605/
# /regulation/tick-pilot/
# /regulation/clearly-erroneous-rule/
# /docs/IEXS BCP Disclosure Statement.pdf
# /regulation/nms-plans/
# /trading/fees/
# /docs/Investors Exchange Rule Book.pdf
# /insights/
# /policy/
# /policy/#letters
# /policy/testimony/2019/
# https://www.facebook.com/IEXTrading
# https://twitter.com/iex
# https://www.instagram.com/iex
# https://www.youtube.com/channel/UC8IVbIhuhzeNS645SQK86OA
# https://www.linkedin.com/company/iex-group-inc-
# https://medium.com/boxes-and-lines
# https://goo.gl/maps/zGkDp52ub1z
# tel:6463432000
# mailto:info@iextrading.com
# https://iexcloud.io/support/
# /patent-notice/
# /trademark-notice/
# /privacy/
# /terms/
